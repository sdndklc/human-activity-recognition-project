# %% [markdown]
# ## Human Activity Recognition Using Smartphones Data

# %% [markdown]
# ## Multilayer Perceptron (MLP)

# %%
# Importing required libraries

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

# %%
# Using GPU

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Loading the data

from google.colab import drive
drive.mount('/content/drive')

data=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Smartphone/Human_Activity_Recognition_Using_Smartphones_Data.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print("Data size: ",data.shape)
# Out:
# Data size:  (10299, 562)

# %%
# Splitting data into input and output

x=data.iloc[:,0:-1]
y=data.iloc[:,-1]

print("Input size: ",x.shape)
print("Output size: ",y.shape)
# Out:
# Input size:  (10299, 561)
# Output size:  (10299,)

# %%
# Getting features used for classification

data_header=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Smartphone/Human_Activity_Recognition_Using_Smartphones_Data.csv",header=None)
features=data_header.iloc[0,0:561]

# Arranging feature names for clarity
features = features.str.replace('[()]','')
features = features.str.replace('[-]', '')
features = features.str.replace('[,]','')

# Printing randomly choosen feature samples
import random
print("Some features:\n\n",random.sample(features.values.tolist(), 8),"\n\n\n")
# Out:
# Some features:
#
#  ['tBodyAcccorrelationYZ', 'fBodyAccbandsEnergy4964', 'fBodyAccmaxIndsZ', 'angleZgravityMean', 'tBodyGyroarCoeffY1', 'tBodyGyroMagmean', 'fBodyAccJerkbandsEnergy1724', 'fBodyAccJerkmeanZ']

# %%
# Encoding labels with digits

original_label=y

print("\n\n Original label samples:\n\n",y[24:30],"\n\n")

y = y.map({'WALKING':1, 'WALKING_UPSTAIRS':2,'WALKING_DOWNSTAIRS':3,\
                       'SITTING':4, 'STANDING':5,'LAYING':6})

print("\n\n Encoded label samples:\n\n",y[24:30])
# Out:
#  Original label samples:
#
#  24    STANDING
# 25    STANDING
# 26    STANDING
# 27     SITTING
# 28     SITTING
# 29     SITTING
# Name: Activity, dtype: object
#
#
#
#
#  Encoded label samples:
#
#  24    5
# 25    5
# 26    5
# 27    4
# 28    4
# 29    4
# Name: Activity, dtype: int64

# %%
# Visualizing the count of the activities

print(data_header.value_counts(original_label),"\n\n\n")

g=sns.countplot(y)
g.set_xticklabels(labels=["Walking","Walking Upstairs","Walking Downstairs","Sitting","Standing","Laying"],rotation=50)
plt.show()
# Out:
# Activity
# LAYING                1944
# STANDING              1906
# SITTING               1777
# WALKING               1722
# WALKING_UPSTAIRS      1544
# WALKING_DOWNSTAIRS    1406
# dtype: int64

# %%
# Splitting data into train and test sets

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print("Train set length:",x_train.shape[0])
print("Test set length:",x_test.shape[0])
# Out:
# Train set length: 8239
# Test set length: 2060

# %%
# Dataframe to tensor 

x_train=torch.tensor(x_train.values)
y_train=torch.tensor(y_train.values)
x_test=torch.tensor(x_test.values)
y_test=torch.tensor(y_test.values)

# %%
# Creating train and test tensors

train=TensorDataset(x_train, y_train)
test=TensorDataset(x_test, y_test)

# %% [markdown]
# ## Neural Network

# %%
class MLP(nn.Module):
    # Initializing layers which will be used in forward propogation
    def __init__(self):
        super(MLP, self).__init__()

        self.fc1 = nn.Linear(input_size, hidden1_size)
        self.fc2 = nn.Linear(hidden1_size, hidden2_size)
        self.fc3 = nn.Linear(hidden2_size, num_classes)
    
    # Implementing forward propogation
    def forward(self, x):
        x = x.view(-1, input_size)

        out1=self.fc1(x)
        act1=torch.relu(out1)

        out2=self.fc2(act1)
        act2=torch.relu(out2)

        out3=self.fc3(act2)
        act3=torch.log_softmax(out3, dim=1)

        return act3

# %%
# Defining parameters

num_epochs =30
input_size = 561
hidden1_size=128
hidden2_size=64
num_classes = 7
num_layers=2

# %%
# Determining loss function

criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ### Tuning batch size, learning rate and epoch number

# %%
for batch_size in [1,10,100]:
    print(f"\n   Batch size: {batch_size}")

    # Defining train and test dataloaders for different batch sizes

    train_loader = DataLoader(train, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(train, batch_size=batch_size, shuffle=False)


    for learning_rate in [0.01,0.005,0.001]:
      print(f"\n>>Learning rate: {learning_rate}")
      

      # Defining model and optimizer for different batch sizes and learning rates
      model=MLP().to(device) 
      optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)  


      # Training 
      for epoch in range(num_epochs):
        for i,(images,labels) in enumerate(train_loader):
          images = images.to(device) 
          labels=labels.to(device) 

          #forward pass
          train_output=model(images.type(torch.float32))
          optimizer.zero_grad()

          #loss
          train_loss=criterion(train_output,labels)

          #backward pass
          train_loss.backward()

          #update
          optimizer.step()


        
        # Prediction and evaluation
        with torch.no_grad(): 
          score=0
          n_samples=0
          for images,labels in test_loader:
            images =images.to(device) 
            labels=labels.to(device) 

            test_output=model(images.type(torch.float32))
            value, index = torch.max(test_output.data, 1)
            predicted_labels=index

            n_samples+=labels.size(0)
            correct_pred=(predicted_labels == labels)
            score+=correct_pred.sum()

          accuracy= score/n_samples*100
          print(f"Epoch [{epoch+1}/{num_epochs}], Accuracy: % {accuracy:.2f}")
# Out:
#    Batch size: 1
#
# >>Learning rate: 0.01
# Epoch [1/30], Accuracy: % 45.49
# Epoch [2/30], Accuracy: % 51.67
# Epoch [3/30], Accuracy: % 49.76
# Epoch [4/30], Accuracy: % 56.74
# Epoch [5/30], Accuracy: % 47.75
# Epoch [6/30], Accuracy: % 55.95
# Epoch [7/30], Accuracy: % 54.56
# Epoch [8/30], Accuracy: % 56.44
# Epoch [9/30], Accuracy: % 58.66
# Epoch [10/30], Accuracy: % 57.82
# Epoch [11/30], Accuracy: % 60.88
# Epoch [12/30], Accuracy: % 60.23
# Epoch [13/30], Accuracy: % 61.20
# Epoch [14/30], Accuracy: % 60.69
# Epoch [15/30], Accuracy: % 61.32
# Epoch [16/30], Accuracy: % 62.60
# Epoch [17/30], Accuracy: % 62.31
# Epoch [18/30], Accuracy: % 61.62
# Epoch [19/30], Accuracy: % 62.14
# Epoch [20/30], Accuracy: % 62.64
# Epoch [21/30], Accuracy: % 59.23
# Epoch [22/30], Accuracy: % 62.79
# Epoch [23/30], Accuracy: % 63.31
# Epoch [24/30], Accuracy: % 61.20
# Epoch [25/30], Accuracy: % 62.03
# Epoch [26/30], Accuracy: % 32.19
# Epoch [27/30], Accuracy: % 60.92
# Epoch [28/30], Accuracy: % 62.00
# Epoch [29/30], Accuracy: % 58.13
# Epoch [30/30], Accuracy: % 62.79
#
# >>Learning rate: 0.005
# Epoch [1/30], Accuracy: % 82.69
# Epoch [2/30], Accuracy: % 88.03
# Epoch [3/30], Accuracy: % 91.92
# Epoch [4/30], Accuracy: % 90.65
# Epoch [5/30], Accuracy: % 94.02
# Epoch [6/30], Accuracy: % 91.10
# Epoch [7/30], Accuracy: % 90.76
# Epoch [8/30], Accuracy: % 83.19
# Epoch [9/30], Accuracy: % 92.17
# Epoch [10/30], Accuracy: % 93.70
# Epoch [11/30], Accuracy: % 95.41
# Epoch [12/30], Accuracy: % 93.80
# Epoch [13/30], Accuracy: % 89.23
# Epoch [14/30], Accuracy: % 91.94
# Epoch [15/30], Accuracy: % 91.27
# Epoch [16/30], Accuracy: % 96.13
# Epoch [17/30], Accuracy: % 92.71
# Epoch [18/30], Accuracy: % 95.44
# Epoch [19/30], Accuracy: % 96.64
# Epoch [20/30], Accuracy: % 96.81
# Epoch [21/30], Accuracy: % 94.84
# Epoch [22/30], Accuracy: % 92.74
# Epoch [23/30], Accuracy: % 93.49
# Epoch [24/30], Accuracy: % 96.01
# Epoch [25/30], Accuracy: % 95.84
# Epoch [26/30], Accuracy: % 92.98
# Epoch [27/30], Accuracy: % 97.27
# Epoch [28/30], Accuracy: % 94.32
# Epoch [29/30], Accuracy: % 95.67
# Epoch [30/30], Accuracy: % 93.36
#
# >>Learning rate: 0.001
# Epoch [1/30], Accuracy: % 90.76
# Epoch [2/30], Accuracy: % 95.51
# Epoch [3/30], Accuracy: % 95.70
# Epoch [4/30], Accuracy: % 93.77
# Epoch [5/30], Accuracy: % 96.59
# Epoch [6/30], Accuracy: % 93.22
# Epoch [7/30], Accuracy: % 98.01
# Epoch [8/30], Accuracy: % 97.94
# Epoch [9/30], Accuracy: % 97.35
# Epoch [10/30], Accuracy: % 96.76
# Epoch [11/30], Accuracy: % 78.29
# Epoch [12/30], Accuracy: % 98.29
# Epoch [13/30], Accuracy: % 98.34
# Epoch [14/30], Accuracy: % 98.19
# Epoch [15/30], Accuracy: % 98.12
# Epoch [16/30], Accuracy: % 94.68
# Epoch [17/30], Accuracy: % 97.63
# Epoch [18/30], Accuracy: % 97.96
# Epoch [19/30], Accuracy: % 98.31
# Epoch [20/30], Accuracy: % 95.65
# Epoch [21/30], Accuracy: % 96.89
# Epoch [22/30], Accuracy: % 98.53
# Epoch [23/30], Accuracy: % 98.02
# Epoch [24/30], Accuracy: % 98.51
# Epoch [25/30], Accuracy: % 98.62
# Epoch [26/30], Accuracy: % 96.89
# Epoch [27/30], Accuracy: % 97.24
# Epoch [28/30], Accuracy: % 98.53
# Epoch [29/30], Accuracy: % 98.23
# Epoch [30/30], Accuracy: % 95.96
#
#    Batch size: 10
#
# >>Learning rate: 0.01
# Epoch [1/30], Accuracy: % 95.19
# Epoch [2/30], Accuracy: % 96.81
# Epoch [3/30], Accuracy: % 95.86
# Epoch [4/30], Accuracy: % 96.19
# Epoch [5/30], Accuracy: % 94.67
# Epoch [6/30], Accuracy: % 93.25
# Epoch [7/30], Accuracy: % 97.80
# Epoch [8/30], Accuracy: % 98.11
# Epoch [9/30], Accuracy: % 96.14
# Epoch [10/30], Accuracy: % 97.96
# Epoch [11/30], Accuracy: % 83.97
# Epoch [12/30], Accuracy: % 96.24
# Epoch [13/30], Accuracy: % 97.05
# Epoch [14/30], Accuracy: % 97.48
# Epoch [15/30], Accuracy: % 97.74
# Epoch [16/30], Accuracy: % 87.41
# Epoch [17/30], Accuracy: % 97.31
# Epoch [18/30], Accuracy: % 97.33
# Epoch [19/30], Accuracy: % 98.30
# Epoch [20/30], Accuracy: % 97.15
# Epoch [21/30], Accuracy: % 98.39
# Epoch [22/30], Accuracy: % 95.91
# Epoch [23/30], Accuracy: % 97.52
# Epoch [24/30], Accuracy: % 96.95
# Epoch [25/30], Accuracy: % 83.04
# Epoch [26/30], Accuracy: % 96.78
# Epoch [27/30], Accuracy: % 89.09
# Epoch [28/30], Accuracy: % 97.58
# Epoch [29/30], Accuracy: % 97.77
# Epoch [30/30], Accuracy: % 97.09
#
# >>Learning rate: 0.005
# Epoch [1/30], Accuracy: % 92.67
# Epoch [2/30], Accuracy: % 88.49
# Epoch [3/30], Accuracy: % 97.28
# Epoch [4/30], Accuracy: % 97.83
# Epoch [5/30], Accuracy: % 96.69
# Epoch [6/30], Accuracy: % 96.61
# Epoch [7/30], Accuracy: % 97.88
# Epoch [8/30], Accuracy: % 97.35
# Epoch [9/30], Accuracy: % 97.33
# Epoch [10/30], Accuracy: % 95.76
# Epoch [11/30], Accuracy: % 98.40
# Epoch [12/30], Accuracy: % 97.46
# Epoch [13/30], Accuracy: % 98.34
# Epoch [14/30], Accuracy: % 97.92
# Epoch [15/30], Accuracy: % 98.35
# Epoch [16/30], Accuracy: % 93.41
# Epoch [17/30], Accuracy: % 96.57
# Epoch [18/30], Accuracy: % 97.82
# Epoch [19/30], Accuracy: % 98.12
# Epoch [20/30], Accuracy: % 98.09
# Epoch [21/30], Accuracy: % 98.35
# Epoch [22/30], Accuracy: % 98.56
# Epoch [23/30], Accuracy: % 98.34
# Epoch [24/30], Accuracy: % 98.14
# Epoch [25/30], Accuracy: % 97.16
# Epoch [26/30], Accuracy: % 94.96
# Epoch [27/30], Accuracy: % 98.43
# Epoch [28/30], Accuracy: % 98.68
# Epoch [29/30], Accuracy: % 98.57
# Epoch [30/30], Accuracy: % 97.29
#
# >>Learning rate: 0.001
# Epoch [1/30], Accuracy: % 94.03
# Epoch [2/30], Accuracy: % 96.60
# Epoch [3/30], Accuracy: % 95.47
# Epoch [4/30], Accuracy: % 97.60
# Epoch [5/30], Accuracy: % 97.83
# Epoch [6/30], Accuracy: % 96.82
# Epoch [7/30], Accuracy: % 97.50
# Epoch [8/30], Accuracy: % 95.52
# Epoch [9/30], Accuracy: % 98.16
# Epoch [10/30], Accuracy: % 95.53
# Epoch [11/30], Accuracy: % 98.14
# Epoch [12/30], Accuracy: % 97.63
# Epoch [13/30], Accuracy: % 97.94
# Epoch [14/30], Accuracy: % 98.09
# Epoch [15/30], Accuracy: % 97.18
# Epoch [16/30], Accuracy: % 97.26
# Epoch [17/30], Accuracy: % 98.36
# Epoch [18/30], Accuracy: % 98.36
# Epoch [19/30], Accuracy: % 98.06
# Epoch [20/30], Accuracy: % 98.48
# Epoch [21/30], Accuracy: % 98.77
# Epoch [22/30], Accuracy: % 97.97
# Epoch [23/30], Accuracy: % 98.40
# Epoch [24/30], Accuracy: % 97.80
# Epoch [25/30], Accuracy: % 98.47
# Epoch [26/30], Accuracy: % 93.66
# Epoch [27/30], Accuracy: % 98.53
# Epoch [28/30], Accuracy: % 98.86
# Epoch [29/30], Accuracy: % 98.63
# Epoch [30/30], Accuracy: % 98.97
#
#    Batch size: 100
#
# >>Learning rate: 0.01
# Epoch [1/30], Accuracy: % 84.65
# Epoch [2/30], Accuracy: % 93.97
# Epoch [3/30], Accuracy: % 96.69
# Epoch [4/30], Accuracy: % 90.62
# Epoch [5/30], Accuracy: % 97.69
# Epoch [6/30], Accuracy: % 95.38
# Epoch [7/30], Accuracy: % 97.63
# Epoch [8/30], Accuracy: % 88.23
# Epoch [9/30], Accuracy: % 95.99
# Epoch [10/30], Accuracy: % 97.38
# Epoch [11/30], Accuracy: % 97.96
# Epoch [12/30], Accuracy: % 98.14
# Epoch [13/30], Accuracy: % 98.41
# Epoch [14/30], Accuracy: % 98.43
# Epoch [15/30], Accuracy: % 98.24
# Epoch [16/30], Accuracy: % 96.47
# Epoch [17/30], Accuracy: % 97.80
# Epoch [18/30], Accuracy: % 97.74
# Epoch [19/30], Accuracy: % 98.20
# Epoch [20/30], Accuracy: % 97.79
# Epoch [21/30], Accuracy: % 98.28
# Epoch [22/30], Accuracy: % 98.64
# Epoch [23/30], Accuracy: % 98.51
# Epoch [24/30], Accuracy: % 98.65
# Epoch [25/30], Accuracy: % 95.91
# Epoch [26/30], Accuracy: % 98.45
# Epoch [27/30], Accuracy: % 98.11
# Epoch [28/30], Accuracy: % 96.07
# Epoch [29/30], Accuracy: % 98.00
# Epoch [30/30], Accuracy: % 98.87
#
# >>Learning rate: 0.005
# Epoch [1/30], Accuracy: % 92.03
# Epoch [2/30], Accuracy: % 95.76
# Epoch [3/30], Accuracy: % 97.15
# Epoch [4/30], Accuracy: % 96.24
# Epoch [5/30], Accuracy: % 97.57
# Epoch [6/30], Accuracy: % 97.61
# Epoch [7/30], Accuracy: % 93.79
# Epoch [8/30], Accuracy: % 97.34
# Epoch [9/30], Accuracy: % 95.36
# Epoch [10/30], Accuracy: % 96.60
# Epoch [11/30], Accuracy: % 96.30
# Epoch [12/30], Accuracy: % 96.32
# Epoch [13/30], Accuracy: % 98.29
# Epoch [14/30], Accuracy: % 97.50
# Epoch [15/30], Accuracy: % 98.02
# Epoch [16/30], Accuracy: % 97.74
# Epoch [17/30], Accuracy: % 98.17
# Epoch [18/30], Accuracy: % 98.46
# Epoch [19/30], Accuracy: % 97.52
# Epoch [20/30], Accuracy: % 98.59
# Epoch [21/30], Accuracy: % 97.67
# Epoch [22/30], Accuracy: % 96.13
# Epoch [23/30], Accuracy: % 98.60
# Epoch [24/30], Accuracy: % 97.20
# Epoch [25/30], Accuracy: % 97.57
# Epoch [26/30], Accuracy: % 97.01
# Epoch [27/30], Accuracy: % 97.33
# Epoch [28/30], Accuracy: % 96.72
# Epoch [29/30], Accuracy: % 98.30
# Epoch [30/30], Accuracy: % 97.92
#
# >>Learning rate: 0.001
# Epoch [1/30], Accuracy: % 79.22
# Epoch [2/30], Accuracy: % 91.41
# Epoch [3/30], Accuracy: % 92.71
# Epoch [4/30], Accuracy: % 94.56
# Epoch [5/30], Accuracy: % 95.62
# Epoch [6/30], Accuracy: % 96.88
# Epoch [7/30], Accuracy: % 95.46
# Epoch [8/30], Accuracy: % 97.45
# Epoch [9/30], Accuracy: % 97.58
# Epoch [10/30], Accuracy: % 97.21
# Epoch [11/30], Accuracy: % 97.96
# Epoch [12/30], Accuracy: % 97.14
# Epoch [13/30], Accuracy: % 97.22
# Epoch [14/30], Accuracy: % 98.03
# Epoch [15/30], Accuracy: % 98.13
# Epoch [16/30], Accuracy: % 97.99
# Epoch [17/30], Accuracy: % 97.56
# Epoch [18/30], Accuracy: % 98.01
# Epoch [19/30], Accuracy: % 98.02
# Epoch [20/30], Accuracy: % 97.80
# Epoch [21/30], Accuracy: % 96.87
# Epoch [22/30], Accuracy: % 98.36
# Epoch [23/30], Accuracy: % 98.31
# Epoch [24/30], Accuracy: % 98.52
# Epoch [25/30], Accuracy: % 98.00
# Epoch [26/30], Accuracy: % 98.57
# Epoch [27/30], Accuracy: % 98.06
# Epoch [28/30], Accuracy: % 98.39
# Epoch [29/30], Accuracy: % 98.29
# Epoch [30/30], Accuracy: % 98.71

# %% [markdown]
# ### Implementing model with chosen parameters

# %%
# Defining optimized parameters

batch_size=10
learning_rate=0.001
num_epochs=30

# Defining dataloaders, model and optimizer for chosen batch size, learning rate, and epoch number

train_loader = DataLoader(train, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(train, batch_size=batch_size, shuffle=False)

model=MLP().to(device) 
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)  



n_iterations=len(train_loader)

# TRAINING

train_loss_list=[]
test_loss_list=[]
accuracy_list=[]
for epoch in range(num_epochs):
  loss_total_train=0
  label_list=[]
  for i,(images,labels) in enumerate(train_loader):
     images = images.to(device) 
     labels=labels.to(device) 

     #forward pass
     train_output=model(images.type(torch.float32))
     optimizer.zero_grad()

     #loss
     train_loss=criterion(train_output,labels)
     loss_total_train+=train_loss

     #backward pass
     train_loss.backward()

     #update
     optimizer.step()

  avg_train_loss=loss_total_train/n_iterations

  # PREDICTION AND EVALUATION
  with torch.no_grad(): 
        score=0
        n_samples=0
        loss_total_test=0
        output_list=[]
        for images,labels in test_loader:
          images = images.to(device)  
          labels=labels.to(device) 
          label_list.extend(labels.numpy())

          test_output=model(images.type(torch.float32))
          value, index = torch.max(test_output.data, 1)
          predicted_labels=index

          n_samples+=labels.size(0)
          correct_pred=(predicted_labels == labels)
          score+=correct_pred.sum()
          output_list.extend(predicted_labels.numpy())

          #test loss
          test_loss=criterion(test_output,labels)
          loss_total_test+=test_loss
        accuracy= score/n_samples*100

        avg_train_loss=loss_total_train/n_iterations
        avg_test_loss=loss_total_test/n_iterations

        accuracy_list.append(accuracy.numpy())
        train_loss_list.append(avg_train_loss.numpy())
        test_loss_list.append(avg_test_loss.numpy())
       


  print (f"Epoch [{epoch+1}/{num_epochs}]: \n train loss= {avg_train_loss:.5f}\n test loss= {avg_test_loss:.5f}\n\n")
print(f"Accuracy:% {accuracy:.2f}")
# Out:
# Epoch [1/30]:
#  train loss= 0.43539
#  test loss= 0.15961
#
#
# Epoch [2/30]:
#  train loss= 0.14936
#  test loss= 0.10173
#
#
# Epoch [3/30]:
#  train loss= 0.10941
#  test loss= 0.09165
#
#
# Epoch [4/30]:
#  train loss= 0.09025
#  test loss= 0.10321
#
#
# Epoch [5/30]:
#  train loss= 0.08603
#  test loss= 0.06355
#
#
# Epoch [6/30]:
#  train loss= 0.07865
#  test loss= 0.13044
#
#
# Epoch [7/30]:
#  train loss= 0.07549
#  test loss= 0.05612
#
#
# Epoch [8/30]:
#  train loss= 0.07414
#  test loss= 0.05875
#
#
# Epoch [9/30]:
#  train loss= 0.06990
#  test loss= 0.10370
#
#
# Epoch [10/30]:
#  train loss= 0.07469
#  test loss= 0.07693
#
#
# Epoch [11/30]:
#  train loss= 0.06221
#  test loss= 0.06732
#
#
# Epoch [12/30]:
#  train loss= 0.06559
#  test loss= 0.04622
#
#
# Epoch [13/30]:
#  train loss= 0.06319
#  test loss= 0.05198
#
#
# Epoch [14/30]:
#  train loss= 0.06585
#  test loss= 0.04770
#
#
# Epoch [15/30]:
#  train loss= 0.05995
#  test loss= 0.04430
#
#
# Epoch [16/30]:
#  train loss= 0.05637
#  test loss= 0.09291
#
#
# Epoch [17/30]:
#  train loss= 0.05941
#  test loss= 0.03747
#
#
# Epoch [18/30]:
#  train loss= 0.04744
#  test loss= 0.07062
#
#
# Epoch [19/30]:
#  train loss= 0.04952
#  test loss= 0.03782
#
#
# Epoch [20/30]:
#  train loss= 0.05783
#  test loss= 0.03201
#
#
# Epoch [21/30]:
#  train loss= 0.04536
#  test loss= 0.08981
#
#
# Epoch [22/30]:
#  train loss= 0.05398
#  test loss= 0.04226
#
#
# Epoch [23/30]:
#  train loss= 0.05142
#  test loss= 0.03056
#
#
# Epoch [24/30]:
#  train loss= 0.04516
#  test loss= 0.06986
#
#
# Epoch [25/30]:
#  train loss= 0.04972
#  test loss= 0.06852
#
#
# Epoch [26/30]:
#  train loss= 0.04335
#  test loss= 0.02776
#
#
# Epoch [27/30]:
#  train loss= 0.03874
#  test loss= 0.02706
#
#
# Epoch [28/30]:
#  train loss= 0.04407
#  test loss= 0.08304
#
#
# Epoch [29/30]:
#  train loss= 0.04932
#  test loss= 0.02692
#
#
# Epoch [30/30]:
#  train loss= 0.03655
#  test loss= 0.02369
#
#
# Accuracy:% 99.05

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# #### Train loss, test loss, accuracy graphs

# %%
plt.figure(1, figsize=(7, 4))
plt.plot(np.arange(1,31,1),train_loss_list)
plt.title('Train loss')
plt.xlabel('Epoch number')

plt.figure(2,figsize=(7, 4))
plt.plot(np.arange(1,31,1),test_loss_list)
plt.title('Test loss')
plt.xlabel('Epoch number')

plt.figure(3,figsize=(7, 4))
plt.plot(np.arange(1,31,1),accuracy_list)
plt.title('Accuracy')
plt.xlabel('Epoch number')
# Out:
# Text(0.5, 0, 'Epoch number')

# %% [markdown]
# #### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report
def show_confusion_matrix(confusion_matrix):
  hmap = sns.heatmap(confusion_matrix, annot=True, fmt="d", cmap="Greens")
  hmap.yaxis.set_ticklabels(hmap.yaxis.get_ticklabels(), rotation=0, ha='right')
  hmap.xaxis.set_ticklabels(hmap.xaxis.get_ticklabels(), rotation=50, ha='right')
  plt.ylabel('Target')
  plt.xlabel('Prediction');

class_names = ["Walking Upstairs","Walking","Sitting","Standing","Walking Downstairs","Laying"]
cm = confusion_matrix(label_list, output_list)
df_cm = pd.DataFrame(cm, index=class_names, columns=class_names)
show_confusion_matrix(df_cm)

# %% [markdown]
# #### Precision, recall and f1-score

# %%
print(classification_report(label_list, output_list))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1353
#            2       1.00      1.00      1.00      1274
#            3       1.00      1.00      1.00      1122
#            4       0.97      0.97      0.97      1400
#            5       0.97      0.98      0.98      1552
#            6       1.00      1.00      1.00      1538
#
#     accuracy                           0.99      8239
#    macro avg       0.99      0.99      0.99      8239
# weighted avg       0.99      0.99      0.99      8239
