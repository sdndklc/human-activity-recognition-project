# %% [markdown]
# ## Human Activity Recognition Using Smartphones Data

# %% [markdown]
# ## LSTM

# %%
# Importing required libraries

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

# %%
# Using GPU

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Loading the data

from google.colab import drive
drive.mount('/content/drive')

data=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Smartphone/Human_Activity_Recognition_Using_Smartphones_Data.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print("Data size: ",data.shape)
# Out:
# Data size:  (10299, 562)

# %%
# Splitting data into input and output

x=data.iloc[:,0:-1]
y=data.iloc[:,-1]

print("Input size: ",x.shape)
print("Output size: ",y.shape)
# Out:
# Input size:  (10299, 561)
# Output size:  (10299,)

# %%
# Getting features used for classification

data_header=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Smartphone/Human_Activity_Recognition_Using_Smartphones_Data.csv",header=None)
features=data_header.iloc[0,0:561]

# Arranging feature names for clarity
features = features.str.replace('[()]','')
features = features.str.replace('[-]', '')
features = features.str.replace('[,]','')

# Printing randomly choosen feature samples
import random
print("Some features:\n\n",random.sample(features.values.tolist(), 8),"\n\n\n")
# Out:
# Some features:
#
#  ['fBodyGyroenergyY', 'tBodyAccJerkcorrelationXZ', 'tBodyAccenergyX', 'tGravityAcciqrY', 'fBodyGyrobandsEnergy2548', 'fBodyGyromeanFreqY', 'fBodyGyrobandsEnergy1732', 'tBodyGyroarCoeffY3']

# %%
# Encoding labels with digits

original_label=y

print("\n\n Original label samples:\n\n",y[24:30],"\n\n")

y = y.map({'WALKING':1, 'WALKING_UPSTAIRS':2,'WALKING_DOWNSTAIRS':3,\
                       'SITTING':4, 'STANDING':5,'LAYING':6})

print("\n\n Encoded label samples:\n\n",y[24:30])
# Out:
#  Original label samples:
#
#  24    STANDING
# 25    STANDING
# 26    STANDING
# 27     SITTING
# 28     SITTING
# 29     SITTING
# Name: Activity, dtype: object
#
#
#
#
#  Encoded label samples:
#
#  24    5
# 25    5
# 26    5
# 27    4
# 28    4
# 29    4
# Name: Activity, dtype: int64

# %%
# Visualizing the count of the activities

print(data_header.value_counts(original_label),"\n\n\n")

g=sns.countplot(y)
g.set_xticklabels(labels=["Walking","Walking Upstairs","Walking Downstairs","Sitting","Standing","Laying"],rotation=50)
plt.show()
# Out:
# Activity
# LAYING                1944
# STANDING              1906
# SITTING               1777
# WALKING               1722
# WALKING_UPSTAIRS      1544
# WALKING_DOWNSTAIRS    1406
# dtype: int64

# %%
# Splitting data into train and test sets

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print("Train set length:",x_train.shape[0])
print("Test set length:",x_test.shape[0])
# Out:
# Train set length: 8239
# Test set length: 2060

# %%
# Dataframe to tensor 

x_train=torch.tensor(x_train.values)
y_train=torch.tensor(y_train.values)
x_test=torch.tensor(x_test.values)
y_test=torch.tensor(y_test.values)

# %%
# Creating train and test tensors

train=TensorDataset(x_train, y_train)
test=TensorDataset(x_test, y_test)

# %% [markdown]
# ## Neural Network

# %%
class LSTM(nn.Module):
  def __init__(self,input_size,hidden_size,num_layers, num_classes):
    super(LSTM,self).__init__()
    self.input_size=input_size
    self.hidden_size=hidden_size
    self.num_layers=num_layers
    self.num_classes=num_classes

    self.LSTM=nn.LSTM(input_size, hidden_size, num_layers,batch_first=True)
    self.fc=nn.Linear(hidden_size,num_classes)

  def forward(self,x):
    h0=torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) 
    c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

    lstm_out, (h_out, c_out) = self.LSTM(x, (h0, c0))
  
    lstm_out =lstm_out[:, -1, :]

    output = self.fc(lstm_out)
 


    return output

# %%
# Defining parameters

num_epochs =30
input_size = 51
sequential_length=11
hidden_size=128
num_classes = 7
num_layers=2

# %%
# Determining loss function

criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ### Tuning batch size, learning rate and epoch number

# %%
for batch_size in [10,100]:
  print(f"\n\n   Batch size: {batch_size}")

  # Defining train and test dataloaders for different batch sizes

  train_loader = DataLoader(train, batch_size=batch_size, shuffle=True)
  test_loader = DataLoader(train, batch_size=batch_size, shuffle=False)


  for learning_rate in [0.01,0.005,0.001]:
    print(f"\n>>Learning rate: {learning_rate}")
    

    # Defining model and optimizer for different batch sizes and learning rates
    model=LSTM(input_size, hidden_size,num_layers, num_classes).to(device) 
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)  


    # Training 
    for epoch in range(num_epochs):
      for i,(images,labels) in enumerate(train_loader):
        images = images.reshape(-1, sequential_length, input_size).to(device) 
        labels=labels.to(device) 

        #forward pass
        train_output=model(images.type(torch.float32))
        optimizer.zero_grad()

        #loss
        train_loss=criterion(train_output,labels)

        #backward pass
        train_loss.backward()

        #update
        optimizer.step()


      
      # Prediction and evaluation
      with torch.no_grad(): 
        score=0
        n_samples=0
        for images,labels in test_loader:
          images =images.reshape(-1, sequential_length, input_size).to(device) 
          labels=labels.to(device) 

          test_output=model(images.type(torch.float32))
          value, index = torch.max(test_output.data, 1)
          predicted_labels=index

          n_samples+=labels.size(0)
          correct_pred=(predicted_labels == labels)
          score+=correct_pred.sum()

        accuracy= score/n_samples*100
        print(f"Epoch [{epoch+1}/{num_epochs}], Accuracy: % {accuracy:.2f}")
# Out:
#    Batch size: 10
#
# >>Learning rate: 0.01
# Epoch [1/30], Accuracy: % 90.48
# Epoch [2/30], Accuracy: % 91.94
# Epoch [3/30], Accuracy: % 91.08
# Epoch [4/30], Accuracy: % 96.26
# Epoch [5/30], Accuracy: % 95.95
# Epoch [6/30], Accuracy: % 96.75
# Epoch [7/30], Accuracy: % 93.85
# Epoch [8/30], Accuracy: % 97.52
# Epoch [9/30], Accuracy: % 96.43
# Epoch [10/30], Accuracy: % 97.78
# Epoch [11/30], Accuracy: % 96.97
# Epoch [12/30], Accuracy: % 94.36
# Epoch [13/30], Accuracy: % 94.37
# Epoch [14/30], Accuracy: % 96.47
# Epoch [15/30], Accuracy: % 98.35
# Epoch [16/30], Accuracy: % 97.96
# Epoch [17/30], Accuracy: % 97.63
# Epoch [18/30], Accuracy: % 97.52
# Epoch [19/30], Accuracy: % 96.64
# Epoch [20/30], Accuracy: % 96.57
# Epoch [21/30], Accuracy: % 98.45
# Epoch [22/30], Accuracy: % 98.18
# Epoch [23/30], Accuracy: % 98.49
# Epoch [24/30], Accuracy: % 94.73
# Epoch [25/30], Accuracy: % 97.24
# Epoch [26/30], Accuracy: % 98.42
# Epoch [27/30], Accuracy: % 97.63
# Epoch [28/30], Accuracy: % 97.50
# Epoch [29/30], Accuracy: % 97.84
# Epoch [30/30], Accuracy: % 97.95
#
# >>Learning rate: 0.005
# Epoch [1/30], Accuracy: % 79.20
# Epoch [2/30], Accuracy: % 90.23
# Epoch [3/30], Accuracy: % 90.98
# Epoch [4/30], Accuracy: % 95.56
# Epoch [5/30], Accuracy: % 92.61
# Epoch [6/30], Accuracy: % 96.67
# Epoch [7/30], Accuracy: % 92.39
# Epoch [8/30], Accuracy: % 96.80
# Epoch [9/30], Accuracy: % 94.76
# Epoch [10/30], Accuracy: % 95.57
# Epoch [11/30], Accuracy: % 96.06
# Epoch [12/30], Accuracy: % 95.62
# Epoch [13/30], Accuracy: % 95.65
# Epoch [14/30], Accuracy: % 96.75
# Epoch [15/30], Accuracy: % 96.86
# Epoch [16/30], Accuracy: % 96.15
# Epoch [17/30], Accuracy: % 96.60
# Epoch [18/30], Accuracy: % 98.28
# Epoch [19/30], Accuracy: % 98.12
# Epoch [20/30], Accuracy: % 98.07
# Epoch [21/30], Accuracy: % 97.99
# Epoch [22/30], Accuracy: % 98.53
# Epoch [23/30], Accuracy: % 99.00
# Epoch [24/30], Accuracy: % 98.19
# Epoch [25/30], Accuracy: % 98.86
# Epoch [26/30], Accuracy: % 98.49
# Epoch [27/30], Accuracy: % 98.59
# Epoch [28/30], Accuracy: % 97.33
# Epoch [29/30], Accuracy: % 98.91
# Epoch [30/30], Accuracy: % 99.15
#
# >>Learning rate: 0.001
# Epoch [1/30], Accuracy: % 89.17
# Epoch [2/30], Accuracy: % 90.53
# Epoch [3/30], Accuracy: % 92.96
# Epoch [4/30], Accuracy: % 93.48
# Epoch [5/30], Accuracy: % 95.93
# Epoch [6/30], Accuracy: % 96.66
# Epoch [7/30], Accuracy: % 95.52
# Epoch [8/30], Accuracy: % 97.40
# Epoch [9/30], Accuracy: % 97.39
# Epoch [10/30], Accuracy: % 97.73
# Epoch [11/30], Accuracy: % 97.85
# Epoch [12/30], Accuracy: % 98.22
# Epoch [13/30], Accuracy: % 98.41
# Epoch [14/30], Accuracy: % 96.25
# Epoch [15/30], Accuracy: % 96.82
# Epoch [16/30], Accuracy: % 97.79
# Epoch [17/30], Accuracy: % 98.39
# Epoch [18/30], Accuracy: % 98.02
# Epoch [19/30], Accuracy: % 98.76
# Epoch [20/30], Accuracy: % 98.76
# Epoch [21/30], Accuracy: % 99.02
# Epoch [22/30], Accuracy: % 98.52
# Epoch [23/30], Accuracy: % 98.80
# Epoch [24/30], Accuracy: % 99.16
# Epoch [25/30], Accuracy: % 98.91
# Epoch [26/30], Accuracy: % 99.10
# Epoch [27/30], Accuracy: % 99.47
# Epoch [28/30], Accuracy: % 98.03
# Epoch [29/30], Accuracy: % 98.57
# Epoch [30/30], Accuracy: % 99.03
#
#
#    Batch size: 100
#
# >>Learning rate: 0.01
# Epoch [1/30], Accuracy: % 45.49
# Epoch [2/30], Accuracy: % 84.62
# Epoch [3/30], Accuracy: % 87.96
# Epoch [4/30], Accuracy: % 93.30
# Epoch [5/30], Accuracy: % 93.83
# Epoch [6/30], Accuracy: % 95.96
# Epoch [7/30], Accuracy: % 95.92
# Epoch [8/30], Accuracy: % 96.95
# Epoch [9/30], Accuracy: % 96.72
# Epoch [10/30], Accuracy: % 98.22
# Epoch [11/30], Accuracy: % 97.89
# Epoch [12/30], Accuracy: % 98.13
# Epoch [13/30], Accuracy: % 98.29
# Epoch [14/30], Accuracy: % 98.66
# Epoch [15/30], Accuracy: % 97.34
# Epoch [16/30], Accuracy: % 98.83
# Epoch [17/30], Accuracy: % 96.64
# Epoch [18/30], Accuracy: % 99.07
# Epoch [19/30], Accuracy: % 97.86
# Epoch [20/30], Accuracy: % 98.42
# Epoch [21/30], Accuracy: % 98.99
# Epoch [22/30], Accuracy: % 98.77
# Epoch [23/30], Accuracy: % 98.83
# Epoch [24/30], Accuracy: % 97.48
# Epoch [25/30], Accuracy: % 96.37
# Epoch [26/30], Accuracy: % 96.24
# Epoch [27/30], Accuracy: % 99.19
# Epoch [28/30], Accuracy: % 99.14
# Epoch [29/30], Accuracy: % 99.24
# Epoch [30/30], Accuracy: % 99.42
#
# >>Learning rate: 0.005
# Epoch [1/30], Accuracy: % 59.42
# Epoch [2/30], Accuracy: % 81.79
# Epoch [3/30], Accuracy: % 92.06
# Epoch [4/30], Accuracy: % 92.72
# Epoch [5/30], Accuracy: % 95.91
# Epoch [6/30], Accuracy: % 95.62
# Epoch [7/30], Accuracy: % 97.17
# Epoch [8/30], Accuracy: % 93.72
# Epoch [9/30], Accuracy: % 97.83
# Epoch [10/30], Accuracy: % 95.35
# Epoch [11/30], Accuracy: % 98.03
# Epoch [12/30], Accuracy: % 97.28
# Epoch [13/30], Accuracy: % 97.52
# Epoch [14/30], Accuracy: % 98.28
# Epoch [15/30], Accuracy: % 98.29
# Epoch [16/30], Accuracy: % 98.76
# Epoch [17/30], Accuracy: % 98.56
# Epoch [18/30], Accuracy: % 97.44
# Epoch [19/30], Accuracy: % 98.17
# Epoch [20/30], Accuracy: % 98.64
# Epoch [21/30], Accuracy: % 98.00
# Epoch [22/30], Accuracy: % 98.70
# Epoch [23/30], Accuracy: % 97.43
# Epoch [24/30], Accuracy: % 97.18
# Epoch [25/30], Accuracy: % 98.63
# Epoch [26/30], Accuracy: % 96.98
# Epoch [27/30], Accuracy: % 99.43
# Epoch [28/30], Accuracy: % 97.95
# Epoch [29/30], Accuracy: % 99.19
# Epoch [30/30], Accuracy: % 99.37
#
# >>Learning rate: 0.001
# Epoch [1/30], Accuracy: % 65.41
# Epoch [2/30], Accuracy: % 73.95
# Epoch [3/30], Accuracy: % 89.59
# Epoch [4/30], Accuracy: % 92.55
# Epoch [5/30], Accuracy: % 88.93
# Epoch [6/30], Accuracy: % 94.56
# Epoch [7/30], Accuracy: % 95.27
# Epoch [8/30], Accuracy: % 95.92
# Epoch [9/30], Accuracy: % 95.17
# Epoch [10/30], Accuracy: % 95.28
# Epoch [11/30], Accuracy: % 93.12
# Epoch [12/30], Accuracy: % 94.00
# Epoch [13/30], Accuracy: % 96.67
# Epoch [14/30], Accuracy: % 96.43
# Epoch [15/30], Accuracy: % 94.30
# Epoch [16/30], Accuracy: % 96.71
# Epoch [17/30], Accuracy: % 97.55
# Epoch [18/30], Accuracy: % 94.48
# Epoch [19/30], Accuracy: % 97.66
# Epoch [20/30], Accuracy: % 93.29
# Epoch [21/30], Accuracy: % 97.23
# Epoch [22/30], Accuracy: % 97.89
# Epoch [23/30], Accuracy: % 82.89
# Epoch [24/30], Accuracy: % 93.83
# Epoch [25/30], Accuracy: % 97.71
# Epoch [26/30], Accuracy: % 98.35
# Epoch [27/30], Accuracy: % 97.90
# Epoch [28/30], Accuracy: % 96.47
# Epoch [29/30], Accuracy: % 98.53
# Epoch [30/30], Accuracy: % 98.01

# %% [markdown]
# ### Implementing model with chosen parameters

# %%
# Defining optimized parameters

batch_size=10
learning_rate=0.001
num_epochs=27

# Defining dataloaders, model and optimizer for chosen batch size, learning rate, and epoch number

train_loader = DataLoader(train, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(train, batch_size=batch_size, shuffle=False)

model=LSTM(input_size, hidden_size,num_layers, num_classes).to(device) 
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)  



n_iterations=len(train_loader)

# TRAINING

train_loss_list=[]
test_loss_list=[]
accuracy_list=[]
for epoch in range(num_epochs):
  loss_total_train=0
  label_list=[]
  for i,(images,labels) in enumerate(train_loader):
     images = images.reshape(-1, sequential_length, input_size).to(device) 
     labels=labels.to(device) 

     #forward pass
     train_output=model(images.type(torch.float32))
     optimizer.zero_grad()

     #loss
     train_loss=criterion(train_output,labels)
     loss_total_train+=train_loss

     #backward pass
     train_loss.backward()

     #update
     optimizer.step()

  avg_train_loss=loss_total_train/n_iterations

  # PREDICTION AND EVALUATION
  with torch.no_grad(): 
        score=0
        n_samples=0
        loss_total_test=0
        output_list=[]
        for images,labels in test_loader:
          images = images.reshape(-1, sequential_length, input_size).to(device)  
          labels=labels.to(device) 
          label_list.extend(labels.numpy())

          test_output=model(images.type(torch.float32))
          value, index = torch.max(test_output.data, 1)
          predicted_labels=index

          n_samples+=labels.size(0)
          correct_pred=(predicted_labels == labels)
          score+=correct_pred.sum()
          output_list.extend(predicted_labels.numpy())

          #test loss
          test_loss=criterion(test_output,labels)
          loss_total_test+=test_loss
        accuracy= score/n_samples*100

        avg_train_loss=loss_total_train/n_iterations
        avg_test_loss=loss_total_test/n_iterations

        accuracy_list.append(accuracy.numpy())
        train_loss_list.append(avg_train_loss.numpy())
        test_loss_list.append(avg_test_loss.numpy())
       


  print (f"Epoch [{epoch+1}/{num_epochs}]: \n train loss= {avg_train_loss:.5f}\n test loss= {avg_test_loss:.5f}\n\n")
print(f"Accuracy:% {accuracy:.2f}")
# Out:
# Epoch [1/27]:
#  train loss= 0.82306
#  test loss= 0.39404
#
#
# Epoch [2/27]:
#  train loss= 0.29061
#  test loss= 0.20613
#
#
# Epoch [3/27]:
#  train loss= 0.19831
#  test loss= 0.20575
#
#
# Epoch [4/27]:
#  train loss= 0.16456
#  test loss= 0.16394
#
#
# Epoch [5/27]:
#  train loss= 0.12947
#  test loss= 0.09300
#
#
# Epoch [6/27]:
#  train loss= 0.11050
#  test loss= 0.08653
#
#
# Epoch [7/27]:
#  train loss= 0.09815
#  test loss= 0.06303
#
#
# Epoch [8/27]:
#  train loss= 0.09010
#  test loss= 0.07249
#
#
# Epoch [9/27]:
#  train loss= 0.07620
#  test loss= 0.05806
#
#
# Epoch [10/27]:
#  train loss= 0.06496
#  test loss= 0.04699
#
#
# Epoch [11/27]:
#  train loss= 0.07443
#  test loss= 0.07241
#
#
# Epoch [12/27]:
#  train loss= 0.06418
#  test loss= 0.05714
#
#
# Epoch [13/27]:
#  train loss= 0.05768
#  test loss= 0.04204
#
#
# Epoch [14/27]:
#  train loss= 0.06015
#  test loss= 0.03925
#
#
# Epoch [15/27]:
#  train loss= 0.05369
#  test loss= 0.03114
#
#
# Epoch [16/27]:
#  train loss= 0.04635
#  test loss= 0.05488
#
#
# Epoch [17/27]:
#  train loss= 0.05743
#  test loss= 0.05537
#
#
# Epoch [18/27]:
#  train loss= 0.04304
#  test loss= 0.02574
#
#
# Epoch [19/27]:
#  train loss= 0.03595
#  test loss= 0.02309
#
#
# Epoch [20/27]:
#  train loss= 0.03759
#  test loss= 0.05118
#
#
# Epoch [21/27]:
#  train loss= 0.03227
#  test loss= 0.02103
#
#
# Epoch [22/27]:
#  train loss= 0.03331
#  test loss= 0.03286
#
#
# Epoch [23/27]:
#  train loss= 0.04585
#  test loss= 0.02703
#
#
# Epoch [24/27]:
#  train loss= 0.02707
#  test loss= 0.02403
#
#
# Epoch [25/27]:
#  train loss= 0.03899
#  test loss= 0.02199
#
#
# Epoch [26/27]:
#  train loss= 0.02231
#  test loss= 0.01879
#
#
# Epoch [27/27]:
#  train loss= 0.02557
#  test loss= 0.01631
#
#
# Accuracy:% 99.32

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# #### Train loss, test loss, accuracy graphs

# %%
plt.figure(1, figsize=(7, 4))
plt.plot(np.arange(1,28,1),train_loss_list)
plt.title('Train loss')
plt.xlabel('Epoch number')

plt.figure(2,figsize=(7, 4))
plt.plot(np.arange(1,28,1),test_loss_list)
plt.title('Test loss')
plt.xlabel('Epoch number')

plt.figure(3,figsize=(7, 4))
plt.plot(np.arange(1,28,1),accuracy_list)
plt.title('Accuracy')
plt.xlabel('Epoch number')
# Out:
# Text(0.5, 0, 'Epoch number')

# %% [markdown]
# #### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report
def show_confusion_matrix(confusion_matrix):
  hmap = sns.heatmap(confusion_matrix, annot=True, fmt="d", cmap="Purples")
  hmap.yaxis.set_ticklabels(hmap.yaxis.get_ticklabels(), rotation=0, ha='right')
  hmap.xaxis.set_ticklabels(hmap.xaxis.get_ticklabels(), rotation=50, ha='right')
  plt.ylabel('Target')
  plt.xlabel('Prediction');

class_names = ["Walking Upstairs","Walking","Sitting","Standing","Walking Downstairs","Laying"]
cm = confusion_matrix(label_list, output_list)
df_cm = pd.DataFrame(cm, index=class_names, columns=class_names)
show_confusion_matrix(df_cm)

# %% [markdown]
# #### Precision, recall and f1-score

# %%
print(classification_report(label_list, output_list))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1353
#            2       1.00      0.99      1.00      1274
#            3       0.99      1.00      1.00      1122
#            4       0.97      0.99      0.98      1400
#            5       0.99      0.97      0.98      1552
#            6       1.00      1.00      1.00      1538
#
#     accuracy                           0.99      8239
#    macro avg       0.99      0.99      0.99      8239
# weighted avg       0.99      0.99      0.99      8239
